# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
ls
# Out:
# 22nd Sept./                             nyc_taxis.csv
# 22nd September.ipynb                    olympics.csv
# 29th Sepember/                          olympics.ipynb
# 8-09-18-First.ipynb                     sample_submission.csv
# 8-09-18-Practice.ipynb                  sample_submission.csv.gz
# 9th September.ipynb                     spam.csv
# Anaconda3-5.2.0-Linux-x86_64.sh.1       sublime_text_3/
# Anaconda3-5.2.0-Linux-x86_64.sh.2       sublime_text_3_build_3176_x64.tar.bz2
# Anaconda3-5.2.0-Linux-x86_64.sh.3       test.csv
# Anaconda3-5.2.0-Linux-x86_64.sh.4       test.csv.gz
# Automobile_data.csv                     train.csv
# brics.csv                               train.csv.gz
# cars.csv                                train_u6lujuX_CVtuZ9i.csv
# college-majors/                         Untitled1.ipynb
# data_description.txt                    Untitled2(1)(1).py
# data-master.zip                         Untitled2(1).py
# ...

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df['SalePrice'].head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
correlation_values = df.select_dtypes(include=[np.number]).corr()

# %%
correlation_values
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
sns.heatmap(correlation_values)

# %%
for i,j in zip(correlation_values['SalePrice'],correlation_values.index):
        if (0.6<i<1) | (-1<i<-0.6):
            print (i,j)
# Out:
# 0.7909816005838047 OverallQual
# 0.6135805515591944 TotalBsmtSF
# 0.6058521846919166 1stFlrSF
# 0.7086244776126511 GrLivArea
# 0.640409197258349 GarageCars
# 0.6234314389183598 GarageArea

# %%
selected_features = correlation_values[["SalePrice"]][(correlation_values["SalePrice"]>=0.6)|(correlation_values["SalePrice"]<=-0.6)]

# %%
X=df[['OverallQual','TotalBsmtSF','GrLivArea','GarageArea','GarageCars','1stFlrSF']]
y=df['SalePrice']

# %%
X_train,X_test,y_train,y_test=tts(X,y,test_size=0.3,random_state=42)

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=reg.fit(X_train,y_train).predict(X_test)

# %%
reg.score(X_test,y_test)#R^2 Goodness of fit
# Out:
# 0.7942740308042102

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))

# %%
rmse
# Out:
# 37888.98391496309
